# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai-D-beep/AIML-2025/blob/main/Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from datetime import datetime

# %%
data={'category':['A','B','C','A','B']}
df=pd.DataFrame(data)
df
# Out:
#   category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B

# %%
label_encoder=LabelEncoder()
df['Label_Encoded']=label_encoder.fit_transform(df['category'])
df
# Out:
#    category  Label_Encoded  category_0  category_1  category_2
# 0         0              0        True       False       False
# 1         1              1       False        True       False
# 2         2              2       False       False        True
# 3         0              0        True       False       False
# 4         1              1       False        True       False

# %%
one_hot_coding=pd.get_dummies(df['category'],prefix='category')
df=pd.concat([df,one_hot_coding],axis=1)
df
# Out:
#    category  Label_Encoded  category_0  category_1  category_2
# 0         0              0        True       False       False
# 1         1              1       False        True       False
# 2         2              2       False       False        True
# 3         0              0        True       False       False
# 4         1              1       False        True       False

# %%
data={'Name':['Alice','Bob'],'Date_Of_Birth':['1990-05-14','1985-08-23']}
df=pd.DataFrame(data)
df
# Out:
#     Name Date_Of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1985-08-23

# %%
df['Date_Of_birth']=pd.to_datetime(df['Date_Of_Birth'])
df
# Out:
#     Name Date_Of_Birth Date_Of_birth
# 0  Alice    1990-05-14    1990-05-14
# 1    Bob    1985-08-23    1985-08-23

# %%
current_year=datetime.now().year
df['Age']=current_year-df['Date_Of_birth'].dt.year
df
# Out:
#     Name Date_Of_Birth Date_Of_birth  Age
# 0  Alice    1990-05-14    1990-05-14   35
# 1    Bob    1985-08-23    1985-08-23   40

# %%
data={'category':['A','B','C','A','B'],'Values':[10,20,15,25,30]}
df=pd.DataFrame(data)
df
# Out:
#   category  Values
# 0        A      10
# 1        B      20
# 2        C      15
# 3        A      25
# 4        B      30

# %%
grouped_df=df.groupby('category').agg({'Values':['sum','mean']})
grouped_df
# Out:
#          Values
#             sum  mean
# category
# A            35  17.5
# B            50  25.0
# C            15  15.0

# %%
pivot=df.pivot_table(index='category',values='Values',aggfunc=['sum','mean'])
pivot
# Out:
#             sum   mean
#          Values Values
# category
# A            35   17.5
# B            50   25.0
# C            15   15.0
